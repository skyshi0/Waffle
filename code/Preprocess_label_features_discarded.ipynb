# %% [markdown]
# ## this notebook is to extract all the investigation events
# 1. Step 1: extract all investigation instances
# 2. Step 2:extract the informationa and features during the investigation
#    1. video sequence
#    2. investigation event ID
#    3. frame start
#    4. frame end
#    5. investigation duration
#    6. paired attack start
#    7. paired attack end
#    8. com_x
#    9. com_y
#    10. linear_speed
#    11. linear_acc
#    12. rotation_speed
#    13. rotation_acc
#    14. label
# 3.  Step: clean and save the data

# %%
#import some packages
import numpy as np
import pandas as pd

# %%
#define some functions for feature extraction
def calc_displacement(x,y):
    """
    displacement: the x,y coordinate difference from the neighboring frames
    pad zero at the beginning
    """
    x_displacement = np.diff(x)
    y_displacement = np.diff(y)
    x_displacement = np.insert(x_displacement,0,0)
    y_displacement = np.insert(y_displacement,0,0)
    return x_displacement, y_displacement

def calc_velocity(x_displacement, y_displacement, dt):
    """
    calculate the velocity from the displacement and ft
    dt: time interval between two frames
    """
    vx = x_displacement / dt
    vy = y_displacement /dt
    return vx, vy

def calc_speed(vx, vy):
    """
    calculate the absolute value of velocity
    """
    speed = np.sqrt((vx**2+vy**2))
    return(speed)

def calc_acc(vx, vy, dt):
    """
    calculate the absolute value of acceleration from the velocity and dt
    dt: time interval between two frames
    """
    accx = np.insert(np.diff(vx),0,0)
    accy = np.insert(np.diff(vy),0,0)
    accx = accx /dt
    accy = accy/dt
    acc = np.sqrt(accx**2+accy**2)
    return (acc)

def head_position(self, earleft, earright):
    head_x = (earleft[:,0]+earright[:,0])/2
    head_y = (earleft[:,1]+earright[:,1])/2
    return head_x, head_y

def center_of_mass(self, keypoints):
    mouse_x = np.mean(keypoints[:,0,:], axis=1)
    mouse_y = np.mean(keypoints[:,1,:], axis=1)
    return mouse_x, mouse_y

def head_mouse_tail_angle(self, head, mouse, tail):
    v1 = head - mouse
    v2 = tail - mouse
    dot_product = np.sum(v1 * v2, axis=1)
    norm_v1 = np.linalg.norm(v1, axis=1)
    norm_v2 = np.linalg.norm(v2, axis=1)
    angle = np.arccos(np.clip(dot_product / (norm_v1 * norm_v2), -1.0, 1.0))
    return angle


def head_to_nose_vector(self, nose, head_x, head_y):
    head_to_nose_x = nose[:,0] - head_x
    head_to_nose_y = nose[:,1] - head_y
    return head_to_nose_x, head_to_nose_y

def head_direction_angle(self, head_to_nose_x, head_to_nose_y):
    head_direction_angle = np.arctan2(head_to_nose_y, head_to_nose_x) #the value range of arctan2 is [-pi,pi] compared to arctan[-pi/2, pi/2]
    return head_direction_angle

def intra_joint_distance(self, keypoints, joint1, joint2):
    return np.linalg.norm(keypoints[:,joint1,:]-keypoints[:,joint2,:], axis=1)

def intra_joint_angle(self, keypoints, joint1, joint2, joint3):
    v1 = keypoints[:,joint1,:]-keypoints[:,joint2,:]
    v2 = keypoints[:,joint3,:]-keypoints[:,joint2,:]
    dot_product = np.sum(v1 * v2, axis=1)
    norm_v1 = np.linalg.norm(v1, axis=1)
    norm_v2 = np.linalg.norm(v2, axis=1)
    # Handle cases where norm is zero to avoid division by zero
    norm_v1[norm_v1 == 0] = 1e-6
    norm_v2[norm_v2 == 0] = 1e-6
    angle = np.arccos(np.clip(dot_product / (norm_v1 * norm_v2), -1.0, 1.0)) # Clip to avoid floating point errors
    return angle


def inter_joint_distance(self, keypoints1, keypoints2, joint1, joint2):
    return np.linalg.norm(keypoints1[:,joint1,:]-keypoints2[:,joint2,:], axis=1)


def inter_joint_angle(self, keypoints1, keypoints2, joint1, joint2, joint3):
    # Angle between vector from joint2 (mouse2) to joint1 (mouse1) and vector from joint2 (mouse2) to joint3 (mouse2)
    v1 = keypoints1[:,joint1,:] - keypoints2[:,joint2,:]
    v2 = keypoints2[:,joint3,:] - keypoints2[:,joint2,:]
    dot_product = np.sum(v1 * v2, axis=1)
    norm_v1 = np.linalg.norm(v1, axis=1)
    norm_v2 = np.linalg.norm(v2, axis=1)
    # Handle cases where norm is zero to avoid division by zero
    norm_v1[norm_v1 == 0] = 1e-6
    norm_v2[norm_v2 == 0] = 1e-6
    angle = np.arccos(np.clip(dot_product / (norm_v1 * norm_v2), -1.0, 1.0))
    return angle

# %%
#define some functions for extracting investigations and paired investigation
#finding the I-A pair
#need a dic to store all -IA pair
#{"pair ID";"investigation_start";"investigation_end";"attack_start";"attack_end";"investigation_duration";"attack_intensity"}

#this function is to extract all start and end time of the investigation and attack behavior
def find_I_A_all(sequence):
    #initialize lists to store the start and end frame index of investigation and attack
    current_behavior = None
    current_start_frame = -1
    investigation_ID = 0 #start from 0
    attack_ID = 0
    for frame_idx, frame_behavior in enumerate(sequence['label']):
        #we use current_behavior as a flag, if the current behavior is not none(not the start), we decide whether it's investigation or attack
        if current_behavior is not None:
            if frame_behavior != current_behavior:
                #if the current frame is not the same behavior as the previous frame
                #we decide whether the previous bout is a investigation bout or an attack bout
                #and reset the flag
                if current_behavior == 1: #1 is investigation
                    sequence['end_frame'] = frame_idx - 1
                    sequence['duration'] = frame_idx - current_investigation_start_frame
                    sequence['investigation_ID'] = investigation_ID 
                    investigation_ID = investigation_ID + 1
                    current_behavior = None
                elif current_behavior == 0: #0 is attack
                    sequence['end_frame'] = frame_idx - 1
                    sequence['duration'] = frame_idx - current_attack_start_frame
                    sequence['attack_ID'] = attack_ID
                    atatck_ID = attack_ID + 1
                    current_behavior = None
                #if the current frame is stil the same behavior as the previous frame
                #we continue the looping
            elif current_behavior ==frame_behavior and current_behavior == 0:
                current_behavior = frame_behavior
            elif current_behavior ==frame_behavior and current_behavior == 1:
                current_behavior = frame_behavior

        #if we just finish a reset(a bout of investigation or attack), we decide whether starts a new investigation bout or attack bout
        if current_behavior is None and frame_behavior ==1:
            current_behavior = 1
            current_investigation_start_frame = frame_idx
            sequence['start_frame'] = current_investigation_start_frame
        elif current_behavior is None and frame_behavior ==0:
            current_behavior = 0
            current_attack_start_frame = frame_idx
            sequence['start_frame'] = current_attack_start_frame

    #deal with the last frame
    if frame_behavior == "investigation":
        sequence['end_frame'] = frame_idx
        sequence['duration'] = frame_idx - current_investigation_start_frame+1
        sequence['investigation_ID'] = investigation_ID 
        investigation_ID = investigation_ID + 1
    if frame_behavior == "attack":
        sequence['end_frame'] = frame_idx
        sequence['duration'] = frame_idx - current_attack_start_frame+1
        sequence['attack_ID'] = attack_ID
        atatck_ID = attack_ID + 1
    print(sequence)
    return(sequence)

def find_I_A_pair(sequence):    
    investigation = sequence[sequence['label']==1]
    attack = sequence[sequence['label']==0]
    investigation_start = investigation['start_frame'].unique()
    investigation_end = investigation['end_frame'].unique()
    attack_start =attack['start_frame'].unique()
    attack_end = attack['end_frame'].unique()

    #print("in")

    investigation_flag =-1
    attack_flag =0
    for i in np.arange(len(attack_start)):
        a_start = attack_start[i]
        a_end = attack_end[i]
        #set the flags

        # Find the most recent preceding investigation
        preceding_investigations = [(i_start, i_end) for i_start, i_end in zip(investigation_start, investigation_end) if i_end < a_start]
       # print(preceding_investigations)
        if preceding_investigations:
            # Get the last one
            #print(preceding_investigations)
            last_investigation_start, last_investigation_end = preceding_investigations[-1]
            if last_investigation_start !=investigation_flag:
                sequence[sequence['start_frame']==last_investigation_start]['paired'] = 1
                investigation_flag = last_investigation_start
            else:
                continue
        else:
            continue
    return(sequence) #[]

# %%
import os
# Check the current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: g:\My Drive\100-PhD Study\110-Courses\2025Summer_Neuromatch\project\code

# %%
len(temp)
# Out:
# 89

# %%
temp = list(sequence)
temp[0][1]['label']
# Out:
# 507738    3
# 507739    1
# 507740    1
# 507741    1
# 507742    1
#          ..
# 531543    3
# 531544    3
# 531545    3
# 531546    3
# 531547    3
# Name: label, Length: 23810, dtype: int64

# %%
sequence_list = list(sequence)
updated_sequence_list = []
for i in range(len(sequence_list)):
    updated_sequence = find_I_A_all(sequence_list[i][1])
    updated_sequence2 = find_I_A_pair(updated_sequence)
    updated_sequence_list.append(updated_sequence2)
# Out:
#         Unnamed: 0                              sequence  frame  \
# 507738      507738  task1/test/mouse071_task1_annotator1      0
# 507739      507739  task1/test/mouse071_task1_annotator1      1
# 507740      507740  task1/test/mouse071_task1_annotator1      2
# 507741      507741  task1/test/mouse071_task1_annotator1      3
# 507742      507742  task1/test/mouse071_task1_annotator1      4
# ...            ...                                   ...    ...
# 531543      531543  task1/test/mouse071_task1_annotator1  23805
# 531544      531544  task1/test/mouse071_task1_annotator1  23806
# 531545      531545  task1/test/mouse071_task1_annotator1  23807
# 531546      531546  task1/test/mouse071_task1_annotator1  23808
# 531547      531547  task1/test/mouse071_task1_annotator1  23809
#
#                                                id  label  resident_x_nose  \
# 507738      task1/test/mouse071_task1_annotator10      3       720.980978
# 507739      task1/test/mouse071_task1_annotator11      1       733.408734
# 507740      task1/test/mouse071_task1_annotator12      1       742.879459
# 507741      task1/test/mouse071_task1_annotator13      1       751.682971
# 507742      task1/test/mouse071_task1_annotator14      1       754.399670
# ...                                           ...    ...              ...
# 531543  task1/test/mouse071_task1_annotator123805      3       276.059134
# 531544  task1/test/mouse071_task1_annotator123806      3       288.333969
# 531545  task1/test/mouse071_task1_annotator123807      3       300.530653
# 531546  task1/test/mouse071_task1_annotator123808      3       302.919795
# 531547  task1/test/mouse071_task1_annotator123809      3       307.115704
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 507738           654.980978            698.980978       661.980978
# 507739           663.408734            705.408734       668.408734
# 507740           670.879459            708.879459       675.879459
# 507741           679.682971            714.682971       681.682971
# 507742           687.399670            722.399670       688.399670
# ...                     ...                   ...              ...
# 531543           201.059134            248.059134       215.059134
# 531544           215.333969            257.333969       223.333969
# 531545           223.530653            261.530653       231.530653
# 531546           233.919795            263.919795       236.919795
# 531547           238.115704            264.115704       238.115704
#
#         resident_x_left_hip  ...  intruder_y_left_ear  intruder_y_right_ear  \
# 507738           550.980978  ...           460.749376            434.749376
# 507739           554.408734  ...           468.161792            438.161792
# 507740           559.879459  ...           471.969705            441.969705
# 507741           568.682971  ...           470.599931            442.599931
# 507742           577.399670  ...           466.060898            436.060898
# ...                     ...  ...                  ...                   ...
# 531543           161.059134  ...           137.209532            183.209532
# 531544           163.333969  ...           135.903511            178.903511
# 531545           163.530653  ...           140.942992            180.942992
# 531546           164.919795  ...           141.070438            181.070438
# 531547           166.115704  ...           142.665989            182.665989
#
#         intruder_y_neck  intruder_y_left_hip  intruder_y_right_hip  \
# 507738       437.749376           404.749376            348.749376
# 507739       442.161792           411.161792            355.161792
# 507740       444.969705           414.969705            359.969705
# 507741       442.599931           418.599931            362.599931
# 507742       436.060898           417.060898            363.060898
# ...                 ...                  ...                   ...
# 531543       150.209532            91.209532            163.209532
# 531544       148.903511            90.903511            161.903511
# 531545       150.942992            90.942992            160.942992
# 531546       151.070438            91.070438            161.070438
# 531547       153.665989            91.665989            161.665989
#
#         intruder_y_tail_base  start_frame  end_frame  duration  \
# 507738            340.749376        23128      23176        49
# 507739            347.161792        23128      23176        49
# 507740            351.969705        23128      23176        49
# 507741            354.599931        23128      23176        49
# 507742            356.060898        23128      23176        49
# ...                      ...          ...        ...       ...
# 531543            114.209532        23128      23176        49
# 531544            112.903511        23128      23176        49
# 531545            112.942992        23128      23176        49
# 531546            113.070438        23128      23176        49
# 531547            112.665989        23128      23176        49
#
#         investigation_ID
# 507738                78
# 507739                78
# 507740                78
# 507741                78
# 507742                78
# ...                  ...
# 531543                78
# 531544                78
# 531545                78
# 531546                78
# 531547                78
#
# [23810 rows x 37 columns]
#         Unnamed: 0                              sequence  frame  \
# 531548      531548  task1/test/mouse072_task1_annotator1      0
# 531549      531549  task1/test/mouse072_task1_annotator1      1
# 531550      531550  task1/test/mouse072_task1_annotator1      2
# 531551      531551  task1/test/mouse072_task1_annotator1      3
# 531552      531552  task1/test/mouse072_task1_annotator1      4
# ...            ...                                   ...    ...
# 549707      549707  task1/test/mouse072_task1_annotator1  18159
# 549708      549708  task1/test/mouse072_task1_annotator1  18160
# 549709      549709  task1/test/mouse072_task1_annotator1  18161
# 549710      549710  task1/test/mouse072_task1_annotator1  18162
# 549711      549711  task1/test/mouse072_task1_annotator1  18163
#
#                                                id  label  resident_x_nose  \
# 531548      task1/test/mouse072_task1_annotator10      3       534.360413
# 531549      task1/test/mouse072_task1_annotator11      1       541.041339
# 531550      task1/test/mouse072_task1_annotator12      1       554.019061
# 531551      task1/test/mouse072_task1_annotator13      1       560.873877
# 531552      task1/test/mouse072_task1_annotator14      1       572.685275
# ...                                           ...    ...              ...
# 549707  task1/test/mouse072_task1_annotator118159      3       227.711057
# 549708  task1/test/mouse072_task1_annotator118160      3       214.733650
# 549709  task1/test/mouse072_task1_annotator118161      3       206.114360
# 549710  task1/test/mouse072_task1_annotator118162      3       198.611873
# 549711  task1/test/mouse072_task1_annotator118163      3       197.093236
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 531548           481.360413            468.360413       461.360413
# 531549           494.041339            480.041339       476.041339
# 531550           504.019061            491.019061       486.019061
# 531551           502.873877            500.873877       490.873877
# 531552           505.685275            505.685275       493.685275
# ...                     ...                   ...              ...
# 549707           146.711057            192.711057       160.711057
# 549708           143.733650            195.733650       161.733650
# 549709           137.114360            197.114360       160.114360
# 549710           132.611873            195.611873       157.611873
# 549711           130.093236            195.093236       157.093236
#
#         resident_x_left_hip  ...  intruder_y_left_ear  intruder_y_right_ear  \
# 531548           365.360413  ...           248.271846            187.271846
# 531549           381.041339  ...           249.280471            187.280471
# 531550           386.019061  ...           246.845303            185.845303
# 531551           403.873877  ...           238.602447            178.602447
# 531552           408.685275  ...           234.494910            170.494910
# ...                     ...  ...                  ...                   ...
# 549707            97.711057  ...           466.376918            459.376918
# 549708            97.733650  ...           463.021030            459.021030
# 549709            98.114360  ...           465.211848            459.211848
# 549710            98.611873  ...           462.366114            458.366114
# 549711            99.093236  ...           463.011924            459.011924
#
#         intruder_y_neck  intruder_y_left_hip  intruder_y_right_hip  \
# 531548       214.271846           231.271846            156.271846
# 531549       214.280471           232.280471            149.280471
# 531550       213.845303           232.845303            157.845303
# 531551       208.602447           234.602447            155.602447
# 531552       201.494910           231.494910            154.494910
# ...                 ...                  ...                   ...
# 549707       449.376918           396.376918            403.376918
# 549708       447.021030           394.021030            403.021030
# 549709       449.211848           396.211848            403.211848
# 549710       446.366114           393.366114            403.366114
# 549711       448.011924           393.011924            404.011924
#
#         intruder_y_tail_base  start_frame  end_frame  duration  \
# 531548            179.271846        16924      16947        24
# 531549            176.280471        16924      16947        24
# 531550            171.845303        16924      16947        24
# 531551            169.602447        16924      16947        24
# 531552            168.494910        16924      16947        24
# ...                      ...          ...        ...       ...
# 549707            369.376918        16924      16947        24
# 549708            367.021030        16924      16947        24
# 549709            367.211848        16924      16947        24
# 549710            367.366114        16924      16947        24
# 549711            368.011924        16924      16947        24
#
#         investigation_ID
# 531548                49
# 531549                49
# 531550                49
# 531551                49
# 531552                49
# ...                  ...
# 549707                49
# 549708                49
# 549709                49
# 549710                49
# 549711                49
#
# [18164 rows x 37 columns]
#         Unnamed: 0                              sequence  frame  \
# 549712      549712  task1/test/mouse073_task1_annotator1      0
# 549713      549713  task1/test/mouse073_task1_annotator1      1
# 549714      549714  task1/test/mouse073_task1_annotator1      2
# 549715      549715  task1/test/mouse073_task1_annotator1      3
# 549716      549716  task1/test/mouse073_task1_annotator1      4
# ...            ...                                   ...    ...
# 568863      568863  task1/test/mouse073_task1_annotator1  19151
# 568864      568864  task1/test/mouse073_task1_annotator1  19152
# 568865      568865  task1/test/mouse073_task1_annotator1  19153
# 568866      568866  task1/test/mouse073_task1_annotator1  19154
# 568867      568867  task1/test/mouse073_task1_annotator1  19155
#
#                                                id  label  resident_x_nose  \
# 549712      task1/test/mouse073_task1_annotator10      3       689.667331
# 549713      task1/test/mouse073_task1_annotator11      1       691.455151
# 549714      task1/test/mouse073_task1_annotator12      1       691.360986
# 549715      task1/test/mouse073_task1_annotator13      1       690.701776
# 549716      task1/test/mouse073_task1_annotator14      1       689.330377
# ...                                           ...    ...              ...
# 568863  task1/test/mouse073_task1_annotator119151      2       221.631500
# 568864  task1/test/mouse073_task1_annotator119152      2       218.844507
# 568865  task1/test/mouse073_task1_annotator119153      2       224.551147
# 568866  task1/test/mouse073_task1_annotator119154      2       228.370639
# 568867  task1/test/mouse073_task1_annotator119155      2       227.773010
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 549712           647.667331            624.667331       624.667331
# 549713           653.455151            627.455151       627.455151
# 549714           656.360986            628.360986       628.360986
# 549715           659.701776            622.701776       628.701776
# 549716           660.330377            623.330377       629.330377
# ...                     ...                   ...              ...
# 568863           261.631500            297.631500       292.631500
# 568864           262.844507            295.844507       290.844507
# 568865           261.551147            300.551147       293.551147
# 568866           265.370639            302.370639       297.370639
# 568867           271.773010            303.773010       302.773010
#
#         resident_x_left_hip  ...  intruder_y_left_ear  intruder_y_right_ear  \
# 549712           570.667331  ...           102.000000             79.000000
# 549713           569.455151  ...            99.000000             80.000000
# 549714           567.360986  ...           100.000000             78.000000
# 549715           567.701776  ...            96.000000             76.000000
# 549716           568.330377  ...            96.000000             79.000000
# ...                     ...  ...                  ...                   ...
# 568863           323.631500  ...           383.788991            420.788991
# 568864           322.844507  ...           383.510103            421.510103
# 568865           324.551147  ...           382.157954            426.157954
# 568866           329.370639  ...           383.292184            423.292184
# 568867           330.773010  ...           377.523428            417.523428
#
#         intruder_y_neck  intruder_y_left_hip  intruder_y_right_hip  \
# 549712        97.000000           138.000000             87.000000
# 549713        98.000000           135.000000             84.000000
# 549714        95.000000           133.000000             85.000000
# 549715        91.000000           132.000000             83.000000
# 549716        93.000000           133.000000             84.000000
# ...                 ...                  ...                   ...
# 568863       391.788991           329.788991            390.788991
# 568864       392.510103           328.510103            389.510103
# 568865       392.157954           327.157954            389.157954
# 568866       391.292184           326.292184            387.292184
# 568867       384.523428           325.523428            381.523428
#
#         intruder_y_tail_base  start_frame  end_frame  duration  \
# 549712            131.000000        18938      18974        37
# 549713            130.000000        18938      18974        37
# 549714            129.000000        18938      18974        37
# 549715            127.000000        18938      18974        37
# 549716            128.000000        18938      18974        37
# ...                      ...          ...        ...       ...
# 568863            325.788991        18938      18974        37
# 568864            322.510103        18938      18974        37
# 568865            322.157954        18938      18974        37
# 568866            319.292184        18938      18974        37
# 568867            315.523428        18938      18974        37
#
#         investigation_ID
# 549712                68
# 549713                68
# 549714                68
# 549715                68
# 549716                68
# ...                  ...
# 568863                68
# 568864                68
# 568865                68
# 568866                68
# 568867                68
#
# [19156 rows x 37 columns]
#         Unnamed: 0                              sequence  frame  \
# 568868      568868  task1/test/mouse074_task1_annotator1      0
# 568869      568869  task1/test/mouse074_task1_annotator1      1
# 568870      568870  task1/test/mouse074_task1_annotator1      2
# 568871      568871  task1/test/mouse074_task1_annotator1      3
# 568872      568872  task1/test/mouse074_task1_annotator1      4
# ...            ...                                   ...    ...
# 587688      587688  task1/test/mouse074_task1_annotator1  18820
# 587689      587689  task1/test/mouse074_task1_annotator1  18821
# 587690      587690  task1/test/mouse074_task1_annotator1  18822
# 587691      587691  task1/test/mouse074_task1_annotator1  18823
# 587692      587692  task1/test/mouse074_task1_annotator1  18824
#
#                                                id  label  resident_x_nose  \
# 568868      task1/test/mouse074_task1_annotator10      3       444.682391
# 568869      task1/test/mouse074_task1_annotator11      3       447.633926
# 568870      task1/test/mouse074_task1_annotator12      3       460.933286
# 568871      task1/test/mouse074_task1_annotator13      3       471.193988
# 568872      task1/test/mouse074_task1_annotator14      3       480.114319
# ...                                           ...    ...              ...
# 587688  task1/test/mouse074_task1_annotator118820      3       767.834662
# 587689  task1/test/mouse074_task1_annotator118821      3       767.768915
# 587690  task1/test/mouse074_task1_annotator118822      3       765.697705
# 587691  task1/test/mouse074_task1_annotator118823      3       762.062817
# 587692  task1/test/mouse074_task1_annotator118824      3       754.488800
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 568868           406.682391            440.682391       406.682391
# 568869           401.633926            439.633926       405.633926
# 568870           398.933286            437.933286       406.933286
# 568871           401.193988            442.193988       409.193988
# 568872           404.114319            442.114319       412.114319
# ...                     ...                   ...              ...
# 587688           788.834662            833.834662       824.834662
# 587689           785.768915            833.768915       821.768915
# 587690           786.697705            832.697705       819.697705
# 587691           784.062817            830.062817       818.062817
# 587692           784.488800            826.488800       818.488800
#
#         resident_x_left_hip  ...  intruder_y_left_ear  intruder_y_right_ear  \
# 568868           318.682391  ...           484.866150            461.866150
# 568869           316.633926  ...           483.302894            462.302894
# 568870           313.933286  ...           482.289284            458.289284
# 568871           316.193988  ...           483.490240            460.490240
# 568872           316.114319  ...           488.421471            465.421471
# ...                     ...  ...                  ...                   ...
# 587688           834.834662  ...           485.650090            428.650090
# 587689           832.768915  ...           485.668518            428.668518
# 587690           829.697705  ...           485.757918            428.757918
# 587691           830.062817  ...           485.666483            429.666483
# 587692           831.488800  ...           486.511860            429.511860
#
#         intruder_y_neck  intruder_y_left_hip  intruder_y_right_hip  \
# 568868       465.866150           457.866150            418.866150
# 568869       463.302894           456.302894            417.302894
# 568870       462.289284           455.289284            415.289284
# 568871       465.490240           455.490240            414.490240
# 568872       468.421471           457.421471            416.421471
# ...                 ...                  ...                   ...
# 587688       453.650090           468.650090            397.650090
# 587689       453.668518           468.668518            397.668518
# 587690       453.757918           468.757918            397.757918
# 587691       453.666483           468.666483            397.666483
# 587692       454.511860           468.511860            397.511860
#
#         intruder_y_tail_base  start_frame  end_frame  duration  \
# 568868            395.866150        18590      18600        11
# 568869            396.302894        18590      18600        11
# 568870            395.289284        18590      18600        11
# 568871            397.490240        18590      18600        11
# 568872            397.421471        18590      18600        11
# ...                      ...          ...        ...       ...
# 587688            407.650090        18590      18600        11
# 587689            407.668518        18590      18600        11
# 587690            407.757918        18590      18600        11
# 587691            407.666483        18590      18600        11
# 587692            407.511860        18590      18600        11
#
#         investigation_ID
# 568868                96
# 568869                96
# 568870                96
# 568871                96
# 568872                96
# ...                  ...
# 587688                96
# 587689                96
# 587690                96
# 587691                96
# 587692                96
#
# [18825 rows x 37 columns]
#         Unnamed: 0                              sequence  frame  \
# 587693      587693  task1/test/mouse075_task1_annotator1      0
# 587694      587694  task1/test/mouse075_task1_annotator1      1
# 587695      587695  task1/test/mouse075_task1_annotator1      2
# 587696      587696  task1/test/mouse075_task1_annotator1      3
# 587697      587697  task1/test/mouse075_task1_annotator1      4
# ...            ...                                   ...    ...
# 605703      605703  task1/test/mouse075_task1_annotator1  18010
# 605704      605704  task1/test/mouse075_task1_annotator1  18011
# 605705      605705  task1/test/mouse075_task1_annotator1  18012
# 605706      605706  task1/test/mouse075_task1_annotator1  18013
# 605707      605707  task1/test/mouse075_task1_annotator1  18014
#
#                                                id  label  resident_x_nose  \
# 587693      task1/test/mouse075_task1_annotator10      3       832.525055
# 587694      task1/test/mouse075_task1_annotator11      1       828.488818
# 587695      task1/test/mouse075_task1_annotator12      1       824.500061
# 587696      task1/test/mouse075_task1_annotator13      1       820.301581
# 587697      task1/test/mouse075_task1_annotator14      1       818.970941
# ...                                           ...    ...              ...
# 605703  task1/test/mouse075_task1_annotator118010      3       265.365982
# 605704  task1/test/mouse075_task1_annotator118011      3       266.608719
# 605705  task1/test/mouse075_task1_annotator118012      3       267.525406
# 605706  task1/test/mouse075_task1_annotator118013      3       267.404971
# 605707  task1/test/mouse075_task1_annotator118014      3       267.490878
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 587693           764.525055            808.525055       778.525055
# 587694           763.488818            810.488818       777.488818
# 587695           758.500061            810.500061       776.500061
# 587696           757.301581            810.301581       777.301581
# 587697           755.970941            809.970941       776.970941
# ...                     ...                   ...              ...
# 605703           226.365982            188.365982       193.365982
# 605704           226.608719            187.608719       192.608719
# 605705           226.525406            188.525406       193.525406
# 605706           227.404971            188.404971       193.404971
# 605707           227.490878            188.490878       193.490878
#
#         resident_x_left_hip  ...  intruder_y_right_ear  intruder_y_neck  \
# 587693           697.525055  ...            412.091779       421.091779
# 587694           699.488818  ...            409.738170       421.738170
# 587695           699.500061  ...            411.407065       423.407065
# 587696           702.301581  ...            411.711041       420.711041
# 587697           704.970941  ...            410.897457       419.897457
# ...                     ...  ...                   ...              ...
# 605703           183.365982  ...            465.880209       435.880209
# 605704           180.608719  ...            465.536610       435.536610
# 605705           183.525406  ...            465.661857       435.661857
# 605706           183.404971  ...            465.293905       436.293905
# 605707           183.490878  ...            465.813367       435.813367
#
#         intruder_y_left_hip  intruder_y_right_hip  intruder_y_tail_base  \
# 587693           489.091779            468.091779            510.091779
# 587694           488.738170            468.738170            512.738170
# 587695           488.407065            467.407065            511.407065
# 587696           485.711041            463.711041            508.711041
# 587697           487.897457            463.897457            507.897457
# ...                     ...                   ...                   ...
# 605703           407.880209            483.880209            491.880209
# 605704           407.536610            484.536610            492.536610
# 605705           409.661857            484.661857            491.661857
# 605706           409.293905            485.293905            493.293905
# 605707           409.813367            484.813367            493.813367
#
#         start_frame  end_frame  duration  investigation_ID  attack_ID
# 587693        16703      16721        19                45          0
# 587694        16703      16721        19                45          0
# 587695        16703      16721        19                45          0
# 587696        16703      16721        19                45          0
# 587697        16703      16721        19                45          0
# ...             ...        ...       ...               ...        ...
# 605703        16703      16721        19                45          0
# 605704        16703      16721        19                45          0
# 605705        16703      16721        19                45          0
# 605706        16703      16721        19                45          0
# 605707        16703      16721        19                45          0
#
# [18015 rows x 38 columns]
#         Unnamed: 0                              sequence  frame  \
# 605708      605708  task1/test/mouse076_task1_annotator1      0
# 605709      605709  task1/test/mouse076_task1_annotator1      1
# 605710      605710  task1/test/mouse076_task1_annotator1      2
# 605711      605711  task1/test/mouse076_task1_annotator1      3
# 605712      605712  task1/test/mouse076_task1_annotator1      4
# ...            ...                                   ...    ...
# 625413      625413  task1/test/mouse076_task1_annotator1  19705
# 625414      625414  task1/test/mouse076_task1_annotator1  19706
# 625415      625415  task1/test/mouse076_task1_annotator1  19707
# 625416      625416  task1/test/mouse076_task1_annotator1  19708
# 625417      625417  task1/test/mouse076_task1_annotator1  19709
#
#                                                id  label  resident_x_nose  \
# 605708      task1/test/mouse076_task1_annotator10      3       771.118353
# 605709      task1/test/mouse076_task1_annotator11      3       753.545038
# 605710      task1/test/mouse076_task1_annotator12      3       739.744684
# 605711      task1/test/mouse076_task1_annotator13      3       730.591107
# 605712      task1/test/mouse076_task1_annotator14      3       724.234277
# ...                                           ...    ...              ...
# 625413  task1/test/mouse076_task1_annotator119705      1       445.149228
# 625414  task1/test/mouse076_task1_annotator119706      1       446.216467
# 625415  task1/test/mouse076_task1_annotator119707      1       419.466202
# 625416  task1/test/mouse076_task1_annotator119708      1       453.488556
# 625417  task1/test/mouse076_task1_annotator119709      1       438.775784
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 605708           826.118353            766.118353       801.118353
# 605709           817.545038            760.545038       795.545038
# 605710           808.744684            753.744684       790.744684
# 605711           801.591107            748.591107       783.591107
# 605712           796.234277            743.234277       778.234277
# ...                     ...                   ...              ...
# 625413           373.149228            406.149228       381.149228
# 625414           376.216467            415.216467       386.216467
# 625415           379.466202            405.466202       377.466202
# 625416           399.488556            414.488556       391.488556
# 625417           396.775784            427.775784       387.775784
#
#         resident_x_left_hip  ...  intruder_y_right_ear  intruder_y_neck  \
# 605708           846.118353  ...            255.781288       257.781288
# 605709           845.545038  ...            255.420130       257.420130
# 605710           845.744684  ...            254.772816       255.772816
# 605711           849.591107  ...            257.482588       257.482588
# 605712           846.234277  ...            255.491734       257.491734
# ...                     ...  ...                   ...              ...
# 625413           345.149228  ...            298.195019       332.195019
# 625414           315.216467  ...            297.631510       319.631510
# 625415           320.466202  ...            336.672733       322.672733
# 625416           319.488556  ...            338.203991       324.203991
# 625417           315.775784  ...            343.505387       325.505387
#
#         intruder_y_left_hip  intruder_y_right_hip  intruder_y_tail_base  \
# 605708           300.781288            304.781288            329.781288
# 605709           300.420130            304.420130            329.420130
# 605710           299.772816            303.772816            328.772816
# 605711           299.482588            304.482588            329.482588
# 605712           297.491734            304.491734            328.491734
# ...                     ...                   ...                   ...
# 625413           356.195019            287.195019            310.195019
# 625414           291.631510            288.631510            285.631510
# 625415           294.672733            290.672733            267.672733
# 625416           292.203991            297.203991            267.203991
# 625417           291.505387            301.505387            267.505387
#
#         start_frame  end_frame  duration  investigation_ID  attack_ID
# 605708        19669      19629         8               119          0
# 605709        19669      19629         8               119          0
# 605710        19669      19629         8               119          0
# 605711        19669      19629         8               119          0
# 605712        19669      19629         8               119          0
# ...             ...        ...       ...               ...        ...
# 625413        19669      19629         8               119          0
# 625414        19669      19629         8               119          0
# 625415        19669      19629         8               119          0
# 625416        19669      19629         8               119          0
# 625417        19669      19629         8               119          0
#
# [19710 rows x 38 columns]
#         Unnamed: 0                              sequence  frame  \
# 625418      625418  task1/test/mouse077_task1_annotator1      0
# 625419      625419  task1/test/mouse077_task1_annotator1      1
# 625420      625420  task1/test/mouse077_task1_annotator1      2
# 625421      625421  task1/test/mouse077_task1_annotator1      3
# 625422      625422  task1/test/mouse077_task1_annotator1      4
# ...            ...                                   ...    ...
# 644320      644320  task1/test/mouse077_task1_annotator1  18902
# 644321      644321  task1/test/mouse077_task1_annotator1  18903
# 644322      644322  task1/test/mouse077_task1_annotator1  18904
# 644323      644323  task1/test/mouse077_task1_annotator1  18905
# 644324      644324  task1/test/mouse077_task1_annotator1  18906
#
#                                                id  label  resident_x_nose  \
# 625418      task1/test/mouse077_task1_annotator10      3       807.999237
# 625419      task1/test/mouse077_task1_annotator11      3       809.258148
# 625420      task1/test/mouse077_task1_annotator12      3       816.363013
# 625421      task1/test/mouse077_task1_annotator13      3       816.154028
# 625422      task1/test/mouse077_task1_annotator14      3       816.070636
# ...                                           ...    ...              ...
# 644320  task1/test/mouse077_task1_annotator118902      3       780.527527
# 644321  task1/test/mouse077_task1_annotator118903      3       779.591559
# 644322  task1/test/mouse077_task1_annotator118904      3       780.546313
# 644323  task1/test/mouse077_task1_annotator118905      3       780.725024
# 644324  task1/test/mouse077_task1_annotator118906      3       780.295148
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 625418           744.999237            780.999237       749.999237
# 625419           749.258148            794.258148       763.258148
# 625420           752.363013            801.363013       767.363013
# 625421           757.154028            807.154028       774.154028
# 625422           757.070636            811.070636       775.070636
# ...                     ...                   ...              ...
# 644320           767.527527            749.527527       744.527527
# 644321           767.591559            749.591559       744.591559
# 644322           767.546313            749.546313       744.546313
# 644323           767.725024            749.725024       744.725024
# 644324           768.295148            749.295148       745.295148
#
#         resident_x_left_hip  ...  intruder_y_right_ear  intruder_y_neck  \
# 625418           659.999237  ...            406.654994       410.654994
# 625419           677.258148  ...            406.821680       410.821680
# 625420           679.363013  ...            407.806639       410.806639
# 625421           686.154028  ...            409.309456       412.309456
# 625422           693.070636  ...            409.567055       413.567055
# ...                     ...  ...                   ...              ...
# 644320           694.527527  ...            397.970152       405.970152
# 644321           693.591559  ...            397.610585       405.610585
# 644322           694.546313  ...            398.484803       406.484803
# 644323           694.725024  ...            397.851608       405.851608
# 644324           694.295148  ...            397.514420       404.514420
#
#         intruder_y_left_hip  intruder_y_right_hip  intruder_y_tail_base  \
# 625418           458.654994            498.654994            516.654994
# 625419           458.821680            498.821680            515.821680
# 625420           458.806639            498.806639            515.806639
# 625421           461.309456            500.309456            515.309456
# 625422           458.567055            500.567055            514.567055
# ...                     ...                   ...                   ...
# 644320           462.970152            481.970152            505.970152
# 644321           463.610585            481.610585            508.610585
# 644322           464.484803            482.484803            509.484803
# 644323           462.851608            481.851608            506.851608
# 644324           462.514420            481.514420            507.514420
#
#         start_frame  end_frame  duration  investigation_ID  attack_ID
# 625418        18140      18153        14                73          0
# 625419        18140      18153        14                73          0
# 625420        18140      18153        14                73          0
# 625421        18140      18153        14                73          0
# 625422        18140      18153        14                73          0
# ...             ...        ...       ...               ...        ...
# 644320        18140      18153        14                73          0
# 644321        18140      18153        14                73          0
# 644322        18140      18153        14                73          0
# 644323        18140      18153        14                73          0
# 644324        18140      18153        14                73          0
#
# [18907 rows x 38 columns]
#         Unnamed: 0                              sequence  frame  \
# 644325      644325  task1/test/mouse078_task1_annotator1      0
# 644326      644326  task1/test/mouse078_task1_annotator1      1
# 644327      644327  task1/test/mouse078_task1_annotator1      2
# 644328      644328  task1/test/mouse078_task1_annotator1      3
# 644329      644329  task1/test/mouse078_task1_annotator1      4
# ...            ...                                   ...    ...
# 663793      663793  task1/test/mouse078_task1_annotator1  19468
# 663794      663794  task1/test/mouse078_task1_annotator1  19469
# 663795      663795  task1/test/mouse078_task1_annotator1  19470
# 663796      663796  task1/test/mouse078_task1_annotator1  19471
# 663797      663797  task1/test/mouse078_task1_annotator1  19472
#
#                                                id  label  resident_x_nose  \
# 644325      task1/test/mouse078_task1_annotator10      3       548.189685
# 644326      task1/test/mouse078_task1_annotator11      0       519.895160
# 644327      task1/test/mouse078_task1_annotator12      0       501.983020
# 644328      task1/test/mouse078_task1_annotator13      0       554.726001
# 644329      task1/test/mouse078_task1_annotator14      0       578.955341
# ...                                           ...    ...              ...
# 663793  task1/test/mouse078_task1_annotator119468      3       888.104065
# 663794  task1/test/mouse078_task1_annotator119469      3       889.137079
# 663795  task1/test/mouse078_task1_annotator119470      3       888.041516
# 663796  task1/test/mouse078_task1_annotator119471      3       888.990442
# 663797  task1/test/mouse078_task1_annotator119472      3       888.611530
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 644325           593.189685            563.189685       596.189685
# 644326           572.895160            534.895160       564.895160
# 644327           524.983020            548.983020       545.983020
# 644328           597.726001            542.726001       562.726001
# 644329           547.955341            570.955341       539.955341
# ...                     ...                   ...              ...
# 663793           825.104065            833.104065       819.104065
# 663794           825.137079            833.137079       820.137079
# 663795           825.041516            833.041516       819.041516
# 663796           824.990442            833.990442       819.990442
# 663797           825.611530            833.611530       819.611530
#
#         resident_x_left_hip  ...  intruder_y_right_ear  intruder_y_neck  \
# 644325           694.189685  ...            181.446430       168.446430
# 644326           659.895160  ...            192.349770       167.349770
# 644327           552.983020  ...            133.456153       154.456153
# 644328           535.726001  ...            182.285636       139.285636
# 644329           456.955341  ...            173.446595       141.446595
# ...                     ...  ...                   ...              ...
# 663793           751.104065  ...            433.879211       471.879211
# 663794           751.137079  ...            433.849252       471.849252
# 663795           751.041516  ...            434.032134       472.032134
# 663796           750.990442  ...            434.440170       472.440170
# 663797           751.611530  ...            434.299498       472.299498
#
#         intruder_y_left_hip  intruder_y_right_hip  intruder_y_tail_base  \
# 644325           125.446430            143.446430            106.446430
# 644326           115.349770            172.349770            133.349770
# 644327           192.456153            137.456153            202.456153
# 644328           177.285636            179.285636            203.285636
# 644329           163.446595            111.446595            229.446595
# ...                     ...                   ...                   ...
# 663793           517.879211            433.879211            490.879211
# 663794           517.849252            433.849252            490.849252
# 663795           518.032134            434.032134            491.032134
# 663796           518.440170            434.440170            491.440170
# 663797           518.299498            434.299498            491.299498
#
#         start_frame  end_frame  duration  attack_ID  investigation_ID
# 644325        19437      19447        11          0               155
# 644326        19437      19447        11          0               155
# 644327        19437      19447        11          0               155
# 644328        19437      19447        11          0               155
# 644329        19437      19447        11          0               155
# ...             ...        ...       ...        ...               ...
# 663793        19437      19447        11          0               155
# 663794        19437      19447        11          0               155
# 663795        19437      19447        11          0               155
# 663796        19437      19447        11          0               155
# 663797        19437      19447        11          0               155
#
# [19473 rows x 38 columns]
#         Unnamed: 0                              sequence  frame  \
# 663798      663798  task1/test/mouse079_task1_annotator1      0
# 663799      663799  task1/test/mouse079_task1_annotator1      1
# 663800      663800  task1/test/mouse079_task1_annotator1      2
# 663801      663801  task1/test/mouse079_task1_annotator1      3
# 663802      663802  task1/test/mouse079_task1_annotator1      4
# ...            ...                                   ...    ...
# 681276      681276  task1/test/mouse079_task1_annotator1  17478
# 681277      681277  task1/test/mouse079_task1_annotator1  17479
# 681278      681278  task1/test/mouse079_task1_annotator1  17480
# 681279      681279  task1/test/mouse079_task1_annotator1  17481
# 681280      681280  task1/test/mouse079_task1_annotator1  17482
#
#                                                id  label  resident_x_nose  \
# 663798      task1/test/mouse079_task1_annotator10      3       727.890808
# 663799      task1/test/mouse079_task1_annotator11      3       726.340881
# 663800      task1/test/mouse079_task1_annotator12      3       724.673462
# 663801      task1/test/mouse079_task1_annotator13      3       725.701526
# 663802      task1/test/mouse079_task1_annotator14      3       725.672583
# ...                                           ...    ...              ...
# 681276  task1/test/mouse079_task1_annotator117478      1       667.246509
# 681277  task1/test/mouse079_task1_annotator117479      1       663.613031
# 681278  task1/test/mouse079_task1_annotator117480      1       661.404181
# 681279  task1/test/mouse079_task1_annotator117481      1       660.800360
# 681280  task1/test/mouse079_task1_annotator117482      1       660.343256
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 663798           748.890808            779.890808       778.890808
# 663799           747.340881            778.340881       774.340881
# 663800           745.673462            776.673462       773.673462
# 663801           743.701526            777.701526       773.701526
# 663802           746.672583            777.672583       773.672583
# ...                     ...                   ...              ...
# 681276           653.246509            697.246509       680.246509
# 681277           649.613031            695.613031       678.613031
# 681278           649.404181            694.404181       676.404181
# 681279           646.800360            692.800360       674.800360
# 681280           646.343256            692.343256       675.343256
#
#         resident_x_left_hip  ...  intruder_y_right_ear  intruder_y_neck  \
# 663798           805.890808  ...            493.036531       487.036531
# 663799           804.340881  ...            492.863881       487.863881
# 663800           803.673462  ...            492.564429       487.564429
# 663801           803.701526  ...            492.288103       490.288103
# 663802           803.672583  ...            493.167484       492.167484
# ...                     ...  ...                   ...              ...
# 681276           678.246509  ...            494.055103       517.055103
# 681277           677.613031  ...            494.669776       516.669776
# 681278           676.404181  ...            493.191070       516.191070
# 681279           675.800360  ...            494.084946       518.084946
# 681280           675.343256  ...            494.424373       518.424373
#
#         intruder_y_left_hip  intruder_y_right_hip  intruder_y_tail_base  \
# 663798           475.036531            446.036531            433.036531
# 663799           472.863881            444.863881            430.863881
# 663800           474.564429            443.564429            430.564429
# 663801           476.288103            445.288103            430.288103
# 663802           477.167484            445.167484            431.167484
# ...                     ...                   ...                   ...
# 681276           539.055103            488.055103            527.055103
# 681277           539.669776            487.669776            531.669776
# 681278           538.191070            511.191070            536.191070
# 681279           540.084946            489.084946            527.084946
# 681280           540.424373            505.424373            531.424373
#
#         start_frame  end_frame  duration  investigation_ID  attack_ID
# 663798        17390      17102        67                61          0
# 663799        17390      17102        67                61          0
# 663800        17390      17102        67                61          0
# 663801        17390      17102        67                61          0
# 663802        17390      17102        67                61          0
# ...             ...        ...       ...               ...        ...
# ...
# ...                     ...  ...                   ...              ...
# 224106           389.348683  ...            161.730940       147.730940
# 224107           394.228989  ...            178.451463       160.451463
# 224108           400.266563  ...            178.112192       160.112192
# 224109           388.054875  ...            182.053639       159.053639
# 224110           387.158540  ...            168.621524       144.621524
#
#         intruder_y_left_hip  intruder_y_right_hip  intruder_y_tail_base  \
# 223049           298.254527            234.254527            272.254527
# 223050           304.948511            221.948511            264.948511
# 223051           306.249670            229.249670            261.249670
# 223052           314.887582            250.887582            279.887582
# 223053           315.932177            245.932177            280.932177
# ...                     ...                   ...                   ...
# 224106           186.730940            242.730940            242.730940
# 224107           184.451463            245.451463            241.451463
# 224108           184.112192            246.112192            238.112192
# 224109           179.053639            241.053639            237.053639
# 224110           175.621524            245.621524            237.621524
#
#         start_frame  end_frame  duration  attack_ID  investigation_ID
# 223049          841        840        38          0                 0
# 223050          841        840        38          0                 0
# 223051          841        840        38          0                 0
# 223052          841        840        38          0                 0
# 223053          841        840        38          0                 0
# ...             ...        ...       ...        ...               ...
# 224106          841        840        38          0                 0
# 224107          841        840        38          0                 0
# 224108          841        840        38          0                 0
# 224109          841        840        38          0                 0
# 224110          841        840        38          0                 0
#
# [1062 rows x 38 columns]
#         Unnamed: 0                               sequence  frame  \
# 224111      224111  task1/train/mouse035_task1_annotator1      0
# 224112      224112  task1/train/mouse035_task1_annotator1      1
# 224113      224113  task1/train/mouse035_task1_annotator1      2
# 224114      224114  task1/train/mouse035_task1_annotator1      3
# 224115      224115  task1/train/mouse035_task1_annotator1      4
# ...            ...                                    ...    ...
# 228985      228985  task1/train/mouse035_task1_annotator1   4874
# 228986      228986  task1/train/mouse035_task1_annotator1   4875
# 228987      228987  task1/train/mouse035_task1_annotator1   4876
# 228988      228988  task1/train/mouse035_task1_annotator1   4877
# 228989      228989  task1/train/mouse035_task1_annotator1   4878
#
#                                                id  label  resident_x_nose  \
# 224111     task1/train/mouse035_task1_annotator10      3       298.993678
# 224112     task1/train/mouse035_task1_annotator11      3       295.167458
# 224113     task1/train/mouse035_task1_annotator12      3       301.360918
# 224114     task1/train/mouse035_task1_annotator13      3       301.279237
# 224115     task1/train/mouse035_task1_annotator14      3       314.116591
# ...                                           ...    ...              ...
# 228985  task1/train/mouse035_task1_annotator14874      1       249.866255
# 228986  task1/train/mouse035_task1_annotator14875      1       262.801506
# 228987  task1/train/mouse035_task1_annotator14876      3       265.164439
# 228988  task1/train/mouse035_task1_annotator14877      3       254.539417
# 228989  task1/train/mouse035_task1_annotator14878      3       235.992181
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 224111           266.993678            248.993678       243.993678
# 224112           272.167458            258.167458       250.167458
# 224113           278.360918            264.360918       256.360918
# 224114           283.279237            269.279237       261.279237
# 224115           292.116591            277.116591       272.116591
# ...                     ...                   ...              ...
# 228985           263.866255            305.866255       295.866255
# 228986           265.801506            319.801506       297.801506
# 228987           264.164439            319.164439       295.164439
# 228988           256.539417            307.539417       289.539417
# 228989           248.992181            296.992181       279.992181
#
#         resident_x_left_hip  ...  intruder_y_left_ear  intruder_y_right_ear  \
# 224111           181.993678  ...           323.872987            329.872987
# 224112           188.167458  ...           321.832877            326.832877
# 224113           203.360918  ...           321.252561            325.252561
# 224114           214.279237  ...           323.633701            323.633701
# 224115           221.116591  ...           323.935361            319.935361
# ...                     ...  ...                  ...                   ...
# 228985           351.866255  ...           282.339301            219.339301
# 228986           327.801506  ...           281.682083            219.682083
# 228987           319.164439  ...           285.485780            220.485780
# 228988           312.539417  ...           282.115089            221.115089
# 228989           317.992181  ...           282.067077            220.067077
#
#         intruder_y_neck  intruder_y_left_hip  intruder_y_right_hip  \
# 224111       342.872987           429.872987            433.872987
# 224112       340.832877           429.832877            433.832877
# 224113       340.252561           429.252561            434.252561
# 224114       338.633701           431.633701            433.633701
# 224115       338.935361           429.935361            430.935361
# ...                 ...                  ...                   ...
# 228985       259.339301           320.339301            290.339301
# 228986       259.682083           319.682083            290.682083
# 228987       261.485780           320.485780            289.485780
# 228988       261.115089           319.115089            295.115089
# 228989       261.067077           319.067077            298.067077
#
#         intruder_y_tail_base  start_frame  end_frame  duration  \
# 224111            487.872987         4868       4875         8
# 224112            488.832877         4868       4875         8
# 224113            488.252561         4868       4875         8
# 224114            487.633701         4868       4875         8
# 224115            485.935361         4868       4875         8
# ...                      ...          ...        ...       ...
# 228985            337.339301         4868       4875         8
# 228986            337.682083         4868       4875         8
# 228987            338.485780         4868       4875         8
# 228988            338.115089         4868       4875         8
# 228989            338.067077         4868       4875         8
#
#         investigation_ID
# 224111                13
# 224112                13
# 224113                13
# 224114                13
# 224115                13
# ...                  ...
# 228985                13
# 228986                13
# 228987                13
# 228988                13
# 228989                13
#
# [4879 rows x 37 columns]
#         Unnamed: 0                               sequence  frame  \
# 228990      228990  task1/train/mouse036_task1_annotator1      0
# 228991      228991  task1/train/mouse036_task1_annotator1      1
# 228992      228992  task1/train/mouse036_task1_annotator1      2
# 228993      228993  task1/train/mouse036_task1_annotator1      3
# 228994      228994  task1/train/mouse036_task1_annotator1      4
# ...            ...                                    ...    ...
# 229081      229081  task1/train/mouse036_task1_annotator1     91
# 229082      229082  task1/train/mouse036_task1_annotator1     92
# 229083      229083  task1/train/mouse036_task1_annotator1     93
# 229084      229084  task1/train/mouse036_task1_annotator1     94
# 229085      229085  task1/train/mouse036_task1_annotator1     95
#
#                                              id  label  resident_x_nose  \
# 228990   task1/train/mouse036_task1_annotator10      3       204.757671
# 228991   task1/train/mouse036_task1_annotator11      3       218.363091
# 228992   task1/train/mouse036_task1_annotator12      3       225.117972
# 228993   task1/train/mouse036_task1_annotator13      3       220.884280
# 228994   task1/train/mouse036_task1_annotator14      3       206.673218
# ...                                         ...    ...              ...
# 229081  task1/train/mouse036_task1_annotator191      0       843.185443
# 229082  task1/train/mouse036_task1_annotator192      0       840.357166
# 229083  task1/train/mouse036_task1_annotator193      0       789.281067
# 229084  task1/train/mouse036_task1_annotator194      0       771.900574
# 229085  task1/train/mouse036_task1_annotator195      0       780.123651
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 228990           257.757671            261.757671       273.757671
# 228991           244.363091            278.363091       273.363091
# 228992           242.117972            272.117972       268.117972
# 228993           238.884280            268.884280       264.884280
# 228994           220.673218            263.673218       254.673218
# ...                     ...                   ...              ...
# 229081           820.185443            798.185443       795.185443
# 229082           815.357166            783.357166       797.357166
# 229083           797.281067            747.281067       766.281067
# 229084           776.900574            729.900574       752.900574
# 229085           783.123651            734.123651       755.123651
#
#         resident_x_left_hip  ...  intruder_x_right_hip  intruder_x_tail_base  \
# 228990           313.757671  ...            715.857178            653.857178
# 228991           299.363091  ...            722.889380            667.889380
# 228992           297.117972  ...            755.659058            705.659058
# 228993           295.884280  ...            832.010803            771.010803
# 228994           289.673218  ...            875.990540            835.990540
# ...                     ...  ...                   ...                   ...
# 229081           779.185443  ...            852.185492            880.185492
# 229082           798.357166  ...            847.120868            896.120868
# 229083           791.281067  ...            847.129028            872.129028
# 229084           794.900574  ...            933.706665            961.706665
# 229085           791.123651  ...            907.487427            905.487427
#
#         intruder_y_nose  intruder_y_left_ear  intruder_y_right_ear  \
# 228990       356.089869           398.089869            346.089869
# 228991       351.458355           396.458355            337.458355
# 228992       339.421355           387.421355            323.421355
# 228993       325.499951           378.499951            313.499951
# 228994       311.723130           366.723130            305.723130
# ...                 ...                  ...                   ...
# 229081       260.339395           322.339395            338.339395
# 229082       211.705226           276.705226            304.705226
# 229083       176.800018           264.800018            221.800018
# 229084       203.002019           213.002019            265.002019
# 229085       121.391047           200.391047            205.391047
#
#         intruder_y_neck  intruder_y_left_hip  intruder_y_right_hip  \
# 228990       372.089869           413.089869            329.089869
# 228991       368.458355           407.458355            336.458355
# 228992       361.421355           401.421355            338.421355
# 228993       353.499951           407.499951            330.499951
# 228994       343.723130           411.723130            331.723130
# ...                 ...                  ...                   ...
# 229081       349.339395           401.339395            396.339395
# 229082       305.705226           369.705226            378.705226
# 229083       270.800018           362.800018            334.800018
# 229084       252.002019           278.002019            278.002019
# 229085       186.391047           236.391047            205.391047
#
#         intruder_y_tail_base  start_frame
# 228990            374.089869           39
# 228991            375.458355           39
# 228992            375.421355           39
# 228993            382.499951           39
# 228994            381.723130           39
# ...                      ...          ...
# 229081            438.339395           39
# 229082            422.705226           39
# 229083            414.800018           39
# 229084            219.002019           39
# 229085            241.391047           39
#
# [96 rows x 34 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\sky\anaconda3\envs\waffles\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'end_frame'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 5
#       3 for i in range(len(sequence_list)):
#       4     updated_sequence = find_I_A_all(sequence_list[i][1])
# ----> 5     updated_sequence2 = find_I_A_pair(updated_sequence)
#       6     updated_sequence_list.append(updated_sequence2)
#
# Cell In[42], line 67, in find_I_A_pair(sequence)
#      65 attack = sequence[sequence['label']==0]
#      66 investigation_start = investigation['start_frame'].unique()
# ---> 67 investigation_end = investigation['end_frame'].unique()
#      68 attack_start =attack['start_frame'].unique()
#      69 attack_end = attack['end_frame'].unique()
#
# File c:\Users\sky\anaconda3\envs\waffles\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\sky\anaconda3\envs\waffles\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'end_frame'

# %%
updated_sequence
# Out:
#         Unnamed: 0                               sequence  frame  \
# 228990      228990  task1/train/mouse036_task1_annotator1      0
# 228991      228991  task1/train/mouse036_task1_annotator1      1
# 228992      228992  task1/train/mouse036_task1_annotator1      2
# 228993      228993  task1/train/mouse036_task1_annotator1      3
# 228994      228994  task1/train/mouse036_task1_annotator1      4
# ...            ...                                    ...    ...
# 229081      229081  task1/train/mouse036_task1_annotator1     91
# 229082      229082  task1/train/mouse036_task1_annotator1     92
# 229083      229083  task1/train/mouse036_task1_annotator1     93
# 229084      229084  task1/train/mouse036_task1_annotator1     94
# 229085      229085  task1/train/mouse036_task1_annotator1     95
#
#                                              id  label  resident_x_nose  \
# 228990   task1/train/mouse036_task1_annotator10      3       204.757671
# 228991   task1/train/mouse036_task1_annotator11      3       218.363091
# 228992   task1/train/mouse036_task1_annotator12      3       225.117972
# 228993   task1/train/mouse036_task1_annotator13      3       220.884280
# 228994   task1/train/mouse036_task1_annotator14      3       206.673218
# ...                                         ...    ...              ...
# 229081  task1/train/mouse036_task1_annotator191      0       843.185443
# 229082  task1/train/mouse036_task1_annotator192      0       840.357166
# 229083  task1/train/mouse036_task1_annotator193      0       789.281067
# 229084  task1/train/mouse036_task1_annotator194      0       771.900574
# 229085  task1/train/mouse036_task1_annotator195      0       780.123651
#
#         resident_x_left_ear  resident_x_right_ear  resident_x_neck  \
# 228990           257.757671            261.757671       273.757671
# 228991           244.363091            278.363091       273.363091
# 228992           242.117972            272.117972       268.117972
# 228993           238.884280            268.884280       264.884280
# 228994           220.673218            263.673218       254.673218
# ...                     ...                   ...              ...
# 229081           820.185443            798.185443       795.185443
# 229082           815.357166            783.357166       797.357166
# 229083           797.281067            747.281067       766.281067
# 229084           776.900574            729.900574       752.900574
# 229085           783.123651            734.123651       755.123651
#
#         resident_x_left_hip  ...  intruder_x_right_hip  intruder_x_tail_base  \
# 228990           313.757671  ...            715.857178            653.857178
# 228991           299.363091  ...            722.889380            667.889380
# 228992           297.117972  ...            755.659058            705.659058
# 228993           295.884280  ...            832.010803            771.010803
# 228994           289.673218  ...            875.990540            835.990540
# ...                     ...  ...                   ...                   ...
# 229081           779.185443  ...            852.185492            880.185492
# 229082           798.357166  ...            847.120868            896.120868
# 229083           791.281067  ...            847.129028            872.129028
# 229084           794.900574  ...            933.706665            961.706665
# 229085           791.123651  ...            907.487427            905.487427
#
#         intruder_y_nose  intruder_y_left_ear  intruder_y_right_ear  \
# 228990       356.089869           398.089869            346.089869
# 228991       351.458355           396.458355            337.458355
# 228992       339.421355           387.421355            323.421355
# 228993       325.499951           378.499951            313.499951
# 228994       311.723130           366.723130            305.723130
# ...                 ...                  ...                   ...
# 229081       260.339395           322.339395            338.339395
# 229082       211.705226           276.705226            304.705226
# 229083       176.800018           264.800018            221.800018
# 229084       203.002019           213.002019            265.002019
# 229085       121.391047           200.391047            205.391047
#
#         intruder_y_neck  intruder_y_left_hip  intruder_y_right_hip  \
# 228990       372.089869           413.089869            329.089869
# 228991       368.458355           407.458355            336.458355
# 228992       361.421355           401.421355            338.421355
# 228993       353.499951           407.499951            330.499951
# 228994       343.723130           411.723130            331.723130
# ...                 ...                  ...                   ...
# 229081       349.339395           401.339395            396.339395
# 229082       305.705226           369.705226            378.705226
# 229083       270.800018           362.800018            334.800018
# 229084       252.002019           278.002019            278.002019
# 229085       186.391047           236.391047            205.391047
#
#         intruder_y_tail_base  start_frame
# 228990            374.089869           39
# 228991            375.458355           39
# 228992            375.421355           39
# 228993            382.499951           39
# 228994            381.723130           39
# ...                      ...          ...
# 229081            438.339395           39
# 229082            422.705226           39
# 229083            414.800018           39
# 229084            219.002019           39
# 229085            241.391047           39
#
# [96 rows x 34 columns]

# %%
import numpy as np
import pandas as pd

# ---------- Helper feature functions ----------
def calc_displacement(x, y):
    x_disp = np.diff(x, prepend=x[0])
    y_disp = np.diff(y, prepend=y[0])
    return x_disp, y_disp

def calc_velocity(x_disp, y_disp, dt):
    return x_disp / dt, y_disp / dt

def calc_speed(vx, vy):
    return np.sqrt(vx**2 + vy**2)

def calc_acc(vx, vy, dt):
    accx = np.diff(vx, prepend=vx[0]) / dt
    accy = np.diff(vy, prepend=vy[0]) / dt
    return np.sqrt(accx**2 + accy**2)

def head_mouse_tail_angle(_, head, mouse, tail):
    v1 = head - mouse
    v2 = tail - mouse
    dot = np.sum(v1 * v2, axis=1)
    norm1 = np.linalg.norm(v1, axis=1)
    norm2 = np.linalg.norm(v2, axis=1)
    norm1[norm1 == 0] = 1e-6
    norm2[norm2 == 0] = 1e-6
    return np.arccos(np.clip(dot / (norm1 * norm2), -1.0, 1.0))

# ---------- Step 1: Extract all investigation/attack bouts ----------
def find_I_A_all(sequence):
    bouts = []
    current_behavior = None
    start_frame = None
    investigation_ID = 0
    attack_ID = 0

    for frame_idx, label in enumerate(sequence['label']):
        if current_behavior is None:
            current_behavior = label
            start_frame = frame_idx
        elif label != current_behavior:
            end_frame = frame_idx - 1
            duration = end_frame - start_frame + 1
            if current_behavior == 1:
                bouts.append({
                    'start_frame': start_frame,
                    'end_frame': end_frame,
                    'label': 1,
                    'investigation_ID': investigation_ID
                })
                investigation_ID += 1
            elif current_behavior == 0:
                bouts.append({
                    'start_frame': start_frame,
                    'end_frame': end_frame,
                    'label': 0,
                    'attack_ID': attack_ID
                })
                attack_ID += 1
            current_behavior = label
            start_frame = frame_idx

    # Handle last bout
    if current_behavior is not None:
        end_frame = len(sequence) - 1
        duration = end_frame - start_frame + 1
        if current_behavior == 1:
            bouts.append({
                'start_frame': start_frame,
                'end_frame': end_frame,
                'label': 1,
                'investigation_ID': investigation_ID
            })
        elif current_behavior == 0:
            bouts.append({
                'start_frame': start_frame,
                'end_frame': end_frame,
                'label': 0,
                'attack_ID': attack_ID
            })

    return pd.DataFrame(bouts)

# ---------- Step 2: Find which investigations are followed by attacks ----------
def find_I_A_pair(bout_df):
    investigation = bout_df[bout_df['label'] == 1].copy()
    attack = bout_df[bout_df['label'] == 0].copy()

    paired_flags = []
    for _, inv in investigation.iterrows():
        inv_end = inv['end_frame']
        # Check if any attack starts shortly after
        followed = any((attack['start_frame'] > inv_end) & (attack['start_frame'] <= inv_end + 15))  # 15-frame window
        paired_flags.append(int(followed))

    investigation['label'] = paired_flags  # overwrite 'label' to 1 if paired
    return investigation.reset_index(drop=True)

# ---------- Step 3: Extract features per investigation bout ----------
def extract_investigation_bouts_with_features(sequence_name, inv_bouts_df, keypoints, dt=1/30):
    features = []

    for _, row in inv_bouts_df.iterrows():
        s, e = row['start_frame'], row['end_frame']
        bout_kp = keypoints[s:e+1]

        # Center of mass
        mouse_x = np.mean(bout_kp[:, 0, :], axis=1)
        mouse_y = np.mean(bout_kp[:, 1, :], axis=1)

        x_disp, y_disp = calc_displacement(mouse_x, mouse_y)
        vx, vy = calc_velocity(x_disp, y_disp, dt)
        speed = calc_speed(vx, vy)
        acc = calc_acc(vx, vy, dt)

        head = (bout_kp[:, 1, :] + bout_kp[:, 2, :]) / 2
        tail = bout_kp[:, -1, :]
        body = np.mean(bout_kp, axis=1)
        angle = head_mouse_tail_angle(None, head, body, tail)
        angle_speed = np.diff(angle, prepend=angle[0]) / dt

        features.append({
            'sequence_name': sequence_name,
            'bout_ID': row['investigation_ID'],
            'start_frame': s,
            'end_frame': e,
            'label': row['label'],
            'mean_speed': np.mean(speed),
            'mean_acc': np.mean(acc),
            'mean_body_angle': np.mean(angle),
            'mean_angle_speed': np.mean(np.abs(angle_speed))
        })

    return features
